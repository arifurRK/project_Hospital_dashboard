# %%
import pandas as pd

# %%
pip install openpyxl
# Out:
# ...
#
# ...
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install xlrd
# Out:
# ...
#      ---------------------------------------- 96.5/96.5 kB 1.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df=pd.read_excel('opd_appointment.xls')

# %%
df
# Out:
#           APPOINT_NO   APPOINT_ID APPOINT_DATE  DOCTOR_NO  SHIFTDTL_NO  \
# 0      1220000785916  12201785916   2022-01-08       2361            2
# 1      1220000785919  12201785919   2022-01-06        766            2
# 2      1220000785925  12201785925   2022-01-05        127            2
# 3      1220000785930  12201785930   2022-01-05        126            2
# 4      1220000785932  12201785932   2022-01-05        237            2
# ...              ...          ...          ...        ...          ...
# 30675  1220000807743  12201807743   2022-03-21        101            2
# 30676  1220000807713  12201807713   2022-03-31        101            2
# 30677  1220000807714  12201807714   2022-03-30        101            2
# 30678  1220000807725  12201807725   2022-03-27        101            2
# 30679  1220000807734  12201807734   2022-03-23        101            2
#
#        CONSULTATION_TYPE  SLOT_SL          SLOT_NO          START_TIME  \
# ...

# %%
df=df.drop('APPOINT_NO','SHIFTDTL_NO','CONSULTATION_TYPE''SLOT_SL''SLOT_NO''START_TIME'	'END_TIME''ROOM_DESC''ROOM_NO''ORDER_SL	REF_CONSULTATION_ID	REFERRED_TO_DOCTOR	ABSENCE_FLAG	AGE	CONSULT_IN_BY	CONSULT_OUT_BY	PAT_FLAG)
