# %%
import numpy as np

# %%
import pandas as pd

# %%
pip install openpyxl

# %%
df=pd.read_excel('Patient info.xlsx')

# %%
df
# Out:
#           APPOINT_NO              PATIENT_NAME PHONE_MOBILE  AGE_YY GENDER  \
# 0      1220000785916             SHAHIDUL ALAM  01860886620    26.0      M
# 1      1220000785919              ABUL HOSSAIN  01711533564    65.0      M
# 2      1220000785925             ZAKIA MAHMUDA  01715064815    47.0      F
# 3      1220000785930           ALOMGIR HOSSAIN  01711394908     NaN      M
# 4      1220000785932  MOHAMMED ALAMGIR HOSSAIN  01713933792    59.0      M
# ...              ...                       ...          ...     ...    ...
# 30675  1220000807743            NAZRUL HOSSAIN  01711812292    51.0      M
# 30676  1220000807713            SHAHINA JASHIM  01648457952    61.0      F
# 30677  1220000807714              PARVIN ISLAM  01882390388    52.0      F
# 30678  1220000807725             SWAPAN SANYAL  01726434683    70.0      M
# 30679  1220000807734           ROKHSANA  AFTAB  01711834031    48.0      F
#
# ...

# %%
df = df.drop_duplicates(subset=['APPOINT_NO','PATIENT_NAME' ,'PHONE_MOBILE' ], keep='last')

# %%
df
# Out:
#           APPOINT_NO              PATIENT_NAME PHONE_MOBILE  AGE_YY GENDER  \
# 0      1220000785916             SHAHIDUL ALAM  01860886620    26.0      M
# 1      1220000785919              ABUL HOSSAIN  01711533564    65.0      M
# 2      1220000785925             ZAKIA MAHMUDA  01715064815    47.0      F
# 3      1220000785930           ALOMGIR HOSSAIN  01711394908     NaN      M
# 4      1220000785932  MOHAMMED ALAMGIR HOSSAIN  01713933792    59.0      M
# ...              ...                       ...          ...     ...    ...
# 30675  1220000807743            NAZRUL HOSSAIN  01711812292    51.0      M
# 30676  1220000807713            SHAHINA JASHIM  01648457952    61.0      F
# 30677  1220000807714              PARVIN ISLAM  01882390388    52.0      F
# 30678  1220000807725             SWAPAN SANYAL  01726434683    70.0      M
# 30679  1220000807734           ROKHSANA  AFTAB  01711834031    48.0      F
#
# ...

# %%
df1=df.drop(['PATIENT_NAME','PHONE_MOBILE','APPOINT_TYPE'],axis=1)

# %%
df1
# Out:
#           APPOINT_NO  AGE_YY GENDER                              ADDRESS  \
# 0      1220000785916    26.0      M          KASHIMPUR, NAWABGONJ, DHAKA
# 1      1220000785919    65.0      M                MURAD NAGAR , CUMILLA
# 2      1220000785925    47.0      F                                  NaN
# 3      1220000785930     NaN      M                                  NaN
# 4      1220000785932    59.0      M        2/4/2,SOUTH KALLAYANPUR,DHAKA
# ...              ...     ...    ...                                  ...
# 30675  1220000807743    51.0      M        46 SAYATORU,LAMA BAZAR,SYLHET
# 30676  1220000807713    61.0      F  RD-12A ,H-83 APT-C3 DHAMONDI ,DHAKA
# 30677  1220000807714    52.0      F              ADARSHA CHASHARA-N.GONJ
# 30678  1220000807725    70.0      M                                  NaN
# 30679  1220000807734    48.0      F     9/A SHELTAC R#1 SHYAMOLI, DHAKA.
#
#        DEPARTMENT_NO
# 0               1019
# 1            4000309
# 2            4000252
# ...

# %%
df2=df1.dropna()

# %%
df2
# Out:
#           APPOINT_NO  AGE_YY GENDER  \
# 0      1220000785916    26.0      M
# 1      1220000785919    65.0      M
# 4      1220000785932    59.0      M
# 6      1220000785940    81.0      M
# 9      1220000785958    40.0      M
# ...              ...     ...    ...
# 30674  1220000807722    64.0      F
# 30675  1220000807743    51.0      M
# 30676  1220000807713    61.0      F
# 30677  1220000807714    52.0      F
# 30679  1220000807734    48.0      F
#
#                                             ADDRESS  DEPARTMENT_NO
# 0                       KASHIMPUR, NAWABGONJ, DHAKA           1019
# 1                             MURAD NAGAR , CUMILLA        4000309
# 4                     2/4/2,SOUTH KALLAYANPUR,DHAKA        4000321
# 6      H-62/2, KALLAYANPUR MAIN ROAD, MIRPUR, DHAKA        4000321
# 9                       19/1,SHAALIBAG,MIRPUR,DHAKA        4000321
# ...                                             ...            ...
# ...

# %%
df2.to_csv('patient_info_primary.csv')

# %%
df2
# Out:
#           APPOINT_NO  AGE_YY GENDER  \
# 0      1220000785916    26.0      M
# 1      1220000785919    65.0      M
# 4      1220000785932    59.0      M
# 6      1220000785940    81.0      M
# 9      1220000785958    40.0      M
# ...              ...     ...    ...
# 30674  1220000807722    64.0      F
# 30675  1220000807743    51.0      M
# 30676  1220000807713    61.0      F
# 30677  1220000807714    52.0      F
# 30679  1220000807734    48.0      F
#
#                                             ADDRESS  DEPARTMENT_NO
# 0                       KASHIMPUR, NAWABGONJ, DHAKA           1019
# 1                             MURAD NAGAR , CUMILLA        4000309
# 4                     2/4/2,SOUTH KALLAYANPUR,DHAKA        4000321
# 6      H-62/2, KALLAYANPUR MAIN ROAD, MIRPUR, DHAKA        4000321
# 9                       19/1,SHAALIBAG,MIRPUR,DHAKA        4000321
# ...                                             ...            ...
# ...
