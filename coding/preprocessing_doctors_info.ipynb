# %%
import pandas as pd

# %%
import numpy as np

# %%
pip install openpyxl
# Out:
# ...
#
# ...
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df=pd.read_excel('C:/Users/Arifurk/HDA-5th-Round-vInternship/project-VInternship/project_hospital_dashboard/raw data/doctor info.xlsx')

# %%
df
# Out:
#           DOCTOR_NO           DEPARTMENT_NAME
# 0      1.200000e+12   ENT & Head-Neck Surgery
# 1      1.250000e+02               Dermatology
# 2      2.450000e+02                  Oncology
# 3      1.250000e+02               Dermatology
# 4      1.370000e+02  Pediatrics & Neonatology
# ...             ...                       ...
# 13895  1.370000e+02  Pediatrics & Neonatology
# 13896  2.280000e+02           General Surgery
# 13897  1.010000e+02                  Oncology
# 13898  1.120000e+02                 Neurology
# 13899  7.660000e+02                 Neurology
#
# [13900 rows x 2 columns]

# %%
df.dropna()
# Out:
#           DOCTOR_NO           DEPARTMENT_NAME
# 0      1.200000e+12   ENT & Head-Neck Surgery
# 1      1.250000e+02               Dermatology
# 2      2.450000e+02                  Oncology
# 3      1.250000e+02               Dermatology
# 4      1.370000e+02  Pediatrics & Neonatology
# ...             ...                       ...
# 13895  1.370000e+02  Pediatrics & Neonatology
# 13896  2.280000e+02           General Surgery
# 13897  1.010000e+02                  Oncology
# 13898  1.120000e+02                 Neurology
# 13899  7.660000e+02                 Neurology
#
# [13882 rows x 2 columns]

# %%
df['DOCTOR_NO']=df['DOCTOR_NO'].astype(int, errors='ignore')

# %%
 df.drop_duplicates(subset=['DOCTOR_NO','DEPARTMENT_NAME'], keep='last')
# Out:
#           DOCTOR_NO                  DEPARTMENT_NAME
# 1084   1.200000e+12                 Vascular Surgery
# 11264  1.200000e+12  Dental and Maxillofacial Center
# 11791  1.310000e+02      Plastic & Aesthetic Surgery
# 11937           NaN               Pediatrics Surgery
# 12057  1.170000e+02       Obstetrics and Gynaecology
# 12364           NaN         Pediatrics & Neonatology
# 12974  1.290000e+02       Obstetrics and Gynaecology
# 13174  1.240000e+02          ENT & Head-Neck Surgery
# 13342  1.200000e+12  Dental and Maxillofacial Center
# 13385  1.200000e+12          ENT & Head-Neck Surgery
# 13508  2.330000e+02                  Cardiac Surgery
# 13626  2.361000e+03                          Urology
# 13724  1.040000e+02       Obstetrics and Gynaecology
# 13725  1.160000e+02                Internal Medicine
# 13744  1.772000e+03                      Orthopedics
# 13775  2.683000e+03                     Rheumatology
# 13776  1.000000e+02               Colorectal Surgery
# ...

# %%
df1= df.drop_duplicates(subset=['DOCTOR_NO','DEPARTMENT_NAME'], keep='last')

# %%
df1
# Out:
#           DOCTOR_NO                  DEPARTMENT_NAME
# 1084   1.200000e+12                 Vascular Surgery
# 11264  1.200000e+12  Dental and Maxillofacial Center
# 11791  1.310000e+02      Plastic & Aesthetic Surgery
# 11937           NaN               Pediatrics Surgery
# 12057  1.170000e+02       Obstetrics and Gynaecology
# 12364           NaN         Pediatrics & Neonatology
# 12974  1.290000e+02       Obstetrics and Gynaecology
# 13174  1.240000e+02          ENT & Head-Neck Surgery
# 13342  1.200000e+12  Dental and Maxillofacial Center
# 13385  1.200000e+12          ENT & Head-Neck Surgery
# 13508  2.330000e+02                  Cardiac Surgery
# 13626  2.361000e+03                          Urology
# 13724  1.040000e+02       Obstetrics and Gynaecology
# 13725  1.160000e+02                Internal Medicine
# 13744  1.772000e+03                      Orthopedics
# 13775  2.683000e+03                     Rheumatology
# 13776  1.000000e+02               Colorectal Surgery
# ...

# %%
df1.head()
# Out:
#           DOCTOR_NO                  DEPARTMENT_NAME
# 1084   1.200000e+12                 Vascular Surgery
# 11264  1.200000e+12  Dental and Maxillofacial Center
# 11791  1.310000e+02      Plastic & Aesthetic Surgery
# 11937           NaN               Pediatrics Surgery
# 12057  1.170000e+02       Obstetrics and Gynaecology

# %%
df1.dropna()
# Out:
#           DOCTOR_NO                  DEPARTMENT_NAME
# 1084   1.200000e+12                 Vascular Surgery
# 11264  1.200000e+12  Dental and Maxillofacial Center
# 11791  1.310000e+02      Plastic & Aesthetic Surgery
# 12057  1.170000e+02       Obstetrics and Gynaecology
# 12974  1.290000e+02       Obstetrics and Gynaecology
# 13174  1.240000e+02          ENT & Head-Neck Surgery
# 13342  1.200000e+12  Dental and Maxillofacial Center
# 13385  1.200000e+12          ENT & Head-Neck Surgery
# 13508  2.330000e+02                  Cardiac Surgery
# 13626  2.361000e+03                          Urology
# 13724  1.040000e+02       Obstetrics and Gynaecology
# 13725  1.160000e+02                Internal Medicine
# 13744  1.772000e+03                      Orthopedics
# 13775  2.683000e+03                     Rheumatology
# 13776  1.000000e+02               Colorectal Surgery
# 13781  2.050000e+02       Obstetrics and Gynaecology
# 13786  1.410000e+02                       Cardiology
# ...

# %%
df1.to_csv('doctors_info_.csv')
